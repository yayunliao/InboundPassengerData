# %%
import pandas as pd
import os
from pandas_ods_reader import read_ods

# %%
folder_name = '旅館業住客類別及國籍人數統計表_csv'
os.makedirs(folder_name, exist_ok=True)

# %%
# 2020年
# 讀.ods檔
data = pd.read_excel('旅館業住客類別及國籍人數統計表/sheet/2020年旅館業住客類別、國籍人數及員工人數統計表-20210228列印.ods', engine='odf', sheet_name=None)

# 每個sheet儲存為csv
for sheet_name, sheet_data in data.items():
    # csv路徑
    csv_file_path = os.path.join(folder_name, f'2020年{sheet_name}月.csv')
    # 儲存為csv
    sheet_data.to_csv(csv_file_path, index=False)
    print(f'Saved {csv_file_path} successfully.')
# Out:
# Saved 旅館業住客類別及國籍人數統計表_csv/2020年1月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2020年2月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2020年3月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2020年4月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2020年5月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2020年6月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2020年7月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2020年8月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2020年9月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2020年10月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2020年11月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2020年12月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2020年1-6月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2020年7-12月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2020年1-12月.csv successfully.

# %%
# 2021年
# 讀.ods檔
data = pd.read_excel('旅館業住客類別及國籍人數統計表/sheet/202101-12旅館國籍住客人數.ods', engine='odf', sheet_name=None)

# 每個sheet儲存為csv
for sheet_name, sheet_data in data.items():
    # csv路徑
    csv_file_path = os.path.join(folder_name, f'2021年{sheet_name}.csv')
    # 儲存為csv
    sheet_data.to_csv(csv_file_path, index=False)
    print(f'Saved {csv_file_path} successfully.')
# Out:
# Saved 旅館業住客類別及國籍人數統計表_csv/2021年1月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2021年2月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2021年3月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2021年4月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2021年5月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2021年6月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2021年7月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2021年8月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2021年9月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2021年10月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2021年11月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2021年12月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2021年1-6月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2021年7-12月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2021年1-12月.csv successfully.

# %%
# 2022年
# 讀.ods檔
data = pd.read_excel('旅館業住客類別及國籍人數統計表/sheet/111年各月 半年 1-12月旅館住客類別及國籍人數統計表.ods', engine='odf', sheet_name=None)

# 每個sheet儲存為csv
for sheet_name, sheet_data in data.items():
    # csv路徑
    csv_file_path = os.path.join(folder_name, f'2022年{sheet_name}.csv')
    # 儲存為csv
    sheet_data.to_csv(csv_file_path, index=False)
    print(f'Saved {csv_file_path} successfully.')
# Out:
# Saved 旅館業住客類別及國籍人數統計表_csv/2022年1月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2022年2月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2022年3月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2022年4月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2022年5月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2022年6月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2022年7月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2022年8月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2022年9月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2022年10月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2022年11月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2022年12月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2022年1-6月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2022年7-12月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2022年1-12月.csv successfully.

# %%
# 2023年
# 讀.ods檔
data = pd.read_excel('旅館業住客類別及國籍人數統計表/sheet/112年1-3月旅館住客類別及國籍人數統計表.ods', engine='odf', sheet_name=None)

# 每個sheet儲存為csv
for sheet_name, sheet_data in data.items():
    # csv路徑
    csv_file_path = os.path.join(folder_name, f'2023年{sheet_name}.csv')
    # 儲存為csv
    sheet_data.to_csv(csv_file_path, index=False)
    print(f'Saved {csv_file_path} successfully.')
# Out:
# Saved 旅館業住客類別及國籍人數統計表_csv/2023年1月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2023年2月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2023年3月.csv successfully.
# Saved 旅館業住客類別及國籍人數統計表_csv/2023年1-3月.csv successfully.

# %%
# 2020年前資料
# 資料夾路徑
folder_path = '旅館業住客類別及國籍人數統計表'
# 輸出資料的資料夾路徑
out_folder_path = '旅館業住客類別及國籍人數統計表_csv'

# 讀取資料夾中的檔案列表
file_names = os.listdir(folder_path)

for file_name in file_names:
    if file_name.endswith('.ods'):
        # 組成檔案路徑
        file_path = os.path.join(folder_path, file_name)
        # 讀.ods檔
        data = pd.read_excel(file_path, engine='odf', sheet_name=None)
        
        for sheet_name, sheet_data in data.items():
            csv_file_name = f'{os.path.splitext(file_name)[0]}_{sheet_name}.csv'
            csv_file_path = os.path.join(out_folder_path, csv_file_name)
            
            # 儲存為csv
            sheet_data.to_csv(csv_file_path, index=False)
            print(f'Saved {csv_file_name} successfully.')
# Out:
# Saved 2019.4旅館住客類別及國籍人數統計表_Worksheet.csv successfully.
# Saved 102年5月旅館住客類別及國籍人數統計表_Worksheet.csv successfully.
# Saved 105年1月旅館住客類別及國籍人數統計表_Worksheet.csv successfully.
# Saved 102年8月旅館住客類別及國籍人數統計表_Worksheet.csv successfully.
# Saved 98年11月旅館住客類別及國籍人數統計表_Worksheet.csv successfully.
# Saved 96年3月旅館住客類別及國籍人數統計表_Worksheet.csv successfully.
# Saved 100年12月旅館住客類別及國籍人數統計表_Worksheet.csv successfully.
# Saved 107年8月旅館住客類別及國籍人數統計表_Worksheet.csv successfully.
# Saved 100年1月旅館住客類別及國籍人數統計表_Worksheet.csv successfully.
# Saved 98年6月旅館住客類別及國籍人數統計表_Worksheet.csv successfully.
# Saved 107年5月旅館住客類別及國籍人數統計表_Worksheet.csv successfully.
# Saved 97年6月旅館住客類別及國籍人數統計表_Worksheet.csv successfully.
# Saved 2019.1旅館住客類別及國籍人數統計表_Worksheet.csv successfully.
# Saved 101年4月旅館住客類別及國籍人數統計表_Worksheet.csv successfully.
# Saved 99年3月旅館住客類別及國籍人數統計表_Worksheet.csv successfully.
# Saved 101年9月旅館住客類別及國籍人數統計表_Worksheet.csv successfully.
# Saved 105年10月旅館住客類別及國籍人數統計表_Worksheet.csv successfully.
# ...
