# %%
'''
匯入套件
'''
# 操作 browser 的 API
from selenium.webdriver.chrome.service import Service
from selenium import webdriver

# 處理逾時例外的工具
from selenium.common.exceptions import TimeoutException

# 面對動態網頁，等待某個元素出現的工具，通常與 exptected_conditions 搭配
from selenium.webdriver.support.ui import WebDriverWait

# 搭配 WebDriverWait 使用，對元素狀態的一種期待條件，若條件發生，則等待結束，往下一行執行
from selenium.webdriver.support import expected_conditions as EC

# 期待元素出現要透過什麼方式指定，通常與 EC、WebDriverWait 一起使用
from selenium.webdriver.common.by import By

# 強制等待 (執行期間休息一下)
from time import sleep

import os

# %%
# 啟動瀏覽器工具的選項
my_options = webdriver.ChromeOptions()
# my_options.add_argument("--headless")                #不開啟實體瀏覽器背景執行
my_options.add_argument("--start-maximized")         #最大化視窗
my_options.add_argument("--incognito")               #開啟無痕模式
my_options.add_argument("--disable-popup-blocking") #禁用彈出攔截
my_options.add_argument("--disable-notifications")  #取消 chrome 推播通知
my_options.add_argument("--lang=zh-TW")  #設定為正體中文

# 建立下載路徑/資料夾，不存在就新增 (os.getcwd() 會取得當前的程式工作目錄)
folderPath = os.path.join(os.getcwd(), 'InboundPassengerData')
if not os.path.exists(folderPath):
    os.makedirs(folderPath)

    
#預設下載路徑
my_options.add_experimental_option("prefs", {
  "download.default_directory": folderPath
})

# 使用 Chrome 的 WebDriver
my_service = Service(executable_path="./chromedriver.exe")
driver = webdriver.Chrome(
    options = my_options,
    service = my_service
)

# %%
# 單一
driver.get('https://stat.taiwan.net.tw/inboundSearch')
for element_id in range(0, 9):
    selector = f"#tab-{element_id}"

    try:
        # 等待網頁搜尋結果
        WebDriverWait(driver, 10).until(
            EC.presence_of_element_located(
                (By.CSS_SELECTOR, selector)
            )
        )
        
        
        element = driver.find_elements(By.CSS_SELECTOR, selector)
        element[1].click()
        
        start_year = driver.find_elements(By.CSS_SELECTOR, '#year>option')
        # 97年
        start_year[1].click()

        sleep(0.5)

        start_month = driver.find_elements(By.CSS_SELECTOR, '.input-md.ng-untouched.ng-pristine.ng-valid>option')
        # 1月
        start_month[1].click()

        sleep(0.5)
        
        # 進階選擇
        selections = driver.find_elements(By.CSS_SELECTOR, 'div>a.more')
        for selection in selections:
            selection.click()
            
        if selector in ('#tab-0', '#tab-1'):
            # click country
            countries = driver.find_elements(By.CSS_SELECTOR, 'input.form-radio')
            for country in countries[3:]:
                country.click()
                sleep(0.3)
                
            # Search
            search = driver.find_element(By.CSS_SELECTOR, 'button.btn.btn-danger')
            search.click()
            sleep(30)

            # csv
            csv = driver.find_element(By.CSS_SELECTOR, 'span>.fa.fa-file-csv-o')
            csv.click()
            sleep(30)

        if selector in ('#tab-2', '#tab-8'):
            # click country
            countries = driver.find_elements(By.CSS_SELECTOR, 'input.form-radio')
            for country in countries[0:]:
                country.click()
                sleep(0.3)
                
            # Search
            search = driver.find_element(By.CSS_SELECTOR, 'button.btn.btn-danger')
            search.click()
            sleep(30)

            # csv
            csv = driver.find_element(By.CSS_SELECTOR, 'span>.fa.fa-file-csv-o')
            csv.click()
            sleep(30)
        
        
        if selector in ('#tab-3', '#tab-4'):
            # click country
            countries = driver.find_elements(By.CSS_SELECTOR, 'input.form-radio')
            for country in countries[8:]:
                country.click()
                sleep(0.3)
            
            # Search
            search = driver.find_element(By.CSS_SELECTOR, 'button.btn.btn-danger')
            search.click()
            sleep(30)

            # csv
            csv = driver.find_element(By.CSS_SELECTOR, 'span>.fa.fa-file-csv-o')
            csv.click()
            sleep(20)

                
        if selector == '#tab-5':
            # click country
            countries = driver.find_elements(By.CSS_SELECTOR, 'input.form-radio')
            for country in countries[9:]:
                country.click()
                sleep(0.3)
            
            # Search
            search = driver.find_element(By.CSS_SELECTOR, 'button.btn.btn-danger')
            search.click()
            sleep(30)

            # csv
            csv = driver.find_element(By.CSS_SELECTOR, 'span>.fa.fa-file-csv-o')
            csv.click()
            sleep(20)

                
        if selector == '#tab-6':
            # click country
            countries = driver.find_elements(By.CSS_SELECTOR, 'input.form-radio')
            for country in countries[14:]:
                country.click()
                sleep(0.3)
                
            # Search
            search = driver.find_element(By.CSS_SELECTOR, 'button.btn.btn-danger')
            search.click()
            sleep(30)

            # csv
            csv = driver.find_element(By.CSS_SELECTOR, 'span>.fa.fa-file-csv-o')
            csv.click()
            sleep(20)
        
        if selector == '#tab-7':
            # click country
            countries = driver.find_elements(By.CSS_SELECTOR, 'input.form-radio')
            for country in countries[11:]:
                country.click()
                sleep(0.3)
            
            # Search
            search = driver.find_element(By.CSS_SELECTOR, 'button.btn.btn-danger')
            search.click()
            sleep(30)

            # csv
            csv = driver.find_element(By.CSS_SELECTOR, 'span>.fa.fa-file-csv-o')
            csv.click()
            sleep(20)

        
        
#         # Search
#         search = driver.find_element(By.CSS_SELECTOR, 'button.btn.btn-danger')
#         search.click()
#         sleep(300)
        
#         # csv
#         csv = driver.find_element(By.CSS_SELECTOR, 'span>.fa.fa-file-csv-o')
#         csv.click()
#         sleep(10)

        driver.get('https://stat.taiwan.net.tw/inboundSearch')

    except TimeoutException:
        print('等待逾時！')

# %%
# 單獨測試單一 #tab-8
driver.get('https://stat.taiwan.net.tw/inboundSearch')
    
element = driver.find_elements(By.CSS_SELECTOR, '#tab-8')
element[1].click()

start_year = driver.find_elements(By.CSS_SELECTOR, '#year>option')
# 97年
start_year[1].click()

sleep(0.5)

start_month = driver.find_elements(By.CSS_SELECTOR, '.input-md.ng-untouched.ng-pristine.ng-valid>option')
# 1月
start_month[1].click()

sleep(0.5)

# 進階選擇
selections = driver.find_elements(By.CSS_SELECTOR, 'div>a.more')
for selection in selections:
    selection.click()
    
countries = driver.find_elements(By.CSS_SELECTOR, 'input.form-radio')
for country in countries[0:]:
    country.click()
    sleep(0.3)
    
# Search
search = driver.find_element(By.CSS_SELECTOR, 'button.btn.btn-danger')
search.click()
sleep(20)

# csv
csv = driver.find_element(By.CSS_SELECTOR, 'span>.fa.fa-file-csv-o')
csv.click()
sleep(10)

# %%
# 關閉網頁
driver.quit()

# %%
# 交叉
driver.get('https://stat.taiwan.net.tw/inboundSearch')

# cross
cross = driver.find_element(By.CSS_SELECTOR, '#ngb-tab-1')
cross.click()

for element_id in range(0, 5):
    selector = f"#tab-{element_id}"

    try:
        # 等待網頁搜尋結果
        WebDriverWait(driver, 10).until(
            EC.presence_of_element_located(
                (By.CSS_SELECTOR, selector)
            )
        )
        
        
        element = driver.find_elements(By.CSS_SELECTOR, selector)
        element[1].click()
        
        start_year = driver.find_elements(By.CSS_SELECTOR, '#year>option')
        # 97年
        start_year[1].click()

        sleep(1)

        start_month = driver.find_elements(By.CSS_SELECTOR, '.input-md.ng-untouched.ng-pristine.ng-valid>option')
        # 1月
        start_month[1].click()

        sleep(2)
        
        if selector in ('#tab-0', '#tab-1'):
            select_all = driver.find_elements(By.CSS_SELECTOR, 'input.form-radio')
            select_all[0].click()
            sleep(0.5)
            select_all[8].click()
            sleep(0.5)
            
             # Search
            search = driver.find_element(By.CSS_SELECTOR, 'button.btn.btn-danger')
            search.click()
            sleep(40)

            # csv
            csv = driver.find_element(By.CSS_SELECTOR, 'span>.fa.fa-file-csv-o')
            csv.click()
            sleep(30)
            
        if selector == '#tab-2':
            select_all = driver.find_elements(By.CSS_SELECTOR, 'input.form-radio')
            select_all[0].click()
            sleep(0.5)
            select_all[3].click()
            sleep(0.5)
            select_all[11].click()
            sleep(0.5)
            
             # Search
            search = driver.find_element(By.CSS_SELECTOR, 'button.btn.btn-danger')
            search.click()
            sleep(40)

            # csv
            csv = driver.find_element(By.CSS_SELECTOR, 'span>.fa.fa-file-csv-o')
            csv.click()
            sleep(30)
        
            
        if selector == '#tab-3':
            
            # 進階選擇
            selections = driver.find_elements(By.CSS_SELECTOR, 'div>a.more')
            for selection in selections:
                selection.click()
            select_all = driver.find_elements(By.CSS_SELECTOR, 'input.form-radio')
            select_all[0].click()
            sleep(0.5)
            select_all[3].click()
            sleep(0.5)
            
            for country in select_all[11:]:
                country.click()
                sleep(0.1)
                
             # Search
            search = driver.find_element(By.CSS_SELECTOR, 'button.btn.btn-danger')
            search.click()
            sleep(200)

            # csv
            csv = driver.find_element(By.CSS_SELECTOR, 'span>.fa.fa-file-csv-o')
            csv.click()
            sleep(40)
        
            
        if selector == '#tab-4':
            # 進階選擇
            selections = driver.find_elements(By.CSS_SELECTOR, 'div>a.more')
            for selection in selections:
                selection.click()
            select_all = driver.find_elements(By.CSS_SELECTOR, 'input.form-radio')
            select_all[0].click()
            sleep(0.5)
            select_all[3].click()
            sleep(0.5)

            for country in select_all[12:]:
                country.click()
                sleep(0.1)
                
             # Search
            search = driver.find_element(By.CSS_SELECTOR, 'button.btn.btn-danger')
            search.click()
            sleep(200)

            # csv
            csv = driver.find_element(By.CSS_SELECTOR, 'span>.fa.fa-file-csv-o')
            csv.click()
            sleep(40)
        
            
        
#         # Search
#         search = driver.find_element(By.CSS_SELECTOR, 'button.btn.btn-danger')
#         search.click()
#         sleep(200)
        
#         # csv
#         csv = driver.find_element(By.CSS_SELECTOR, 'span>.fa.fa-file-csv-o')
#         csv.click()
#         sleep(30)

        # 交叉
        driver.get('https://stat.taiwan.net.tw/inboundSearch')
        sleep(1)
        # cross
        cross = driver.find_element(By.CSS_SELECTOR, '#ngb-tab-1')
        cross.click()

    except TimeoutException:
        print('等待逾時！')

# %%
driver.quit()

# %%
# 單獨測試交叉 #tab-4
driver.get('https://stat.taiwan.net.tw/inboundSearch')

# cross
cross = driver.find_element(By.CSS_SELECTOR, '#ngb-tab-1')
cross.click()

element = driver.find_elements(By.CSS_SELECTOR, '#tab-4')
element[1].click()
                               
start_year = driver.find_elements(By.CSS_SELECTOR, '#year>option')
# 97年
start_year[1].click()
sleep(1)

start_month = driver.find_elements(By.CSS_SELECTOR, '.input-md.ng-untouched.ng-pristine.ng-valid>option')
# 1月
start_month[1].click()
sleep(2)
                               
selections = driver.find_elements(By.CSS_SELECTOR, 'div>a.more')
for selection in selections:
    selection.click()
select_all = driver.find_elements(By.CSS_SELECTOR, 'input.form-radio')
select_all[0].click()
sleep(0.5)
select_all[3].click()
sleep(0.5)

for country in select_all[12:]:
    country.click()
    sleep(0.1)
                               
# Search
search = driver.find_element(By.CSS_SELECTOR, 'button.btn.btn-danger')
search.click()
sleep(200)

# csv
csv = driver.find_element(By.CSS_SELECTOR, 'span>.fa.fa-file-csv-o')
csv.click()
sleep(30)
